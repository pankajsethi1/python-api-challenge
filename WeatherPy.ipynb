# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=metric&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | siljan
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | tubmanburg
# Processing Record 6 of Set 1 | sereflikochisar
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | rafai
# Processing Record 9 of Set 1 | saint-joseph
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | antofagasta
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | sarangani
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | santa isabel do rio negro
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | jalu
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | alice springs
# Processing Record 25 of Set 1 | shenjiamen
# Processing Record 26 of Set 1 | codrington
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | fare
# Processing Record 30 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 1 | gannan
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | kadaya
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | hinatuan
# Processing Record 37 of Set 1 | huntsville
# Processing Record 38 of Set 1 | saint-francois
# Processing Record 39 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | marang
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | onega
# Processing Record 48 of Set 1 | taga
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | bentiu
# Processing Record 0 of Set 2 | aklavik
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | victor harbor
# Processing Record 5 of Set 2 | vardo
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | vershino-darasunskiy
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 2 | ridgecrest
# Processing Record 11 of Set 2 | buchanan
# Processing Record 12 of Set 2 | port macquarie
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | brae
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | juquitiba
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | omsk
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 2 | hobyo
# Processing Record 22 of Set 2 | neiafu
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | anloga
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | beaverlodge
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | ucluelet
# Processing Record 31 of Set 2 | grand gaube
# Processing Record 32 of Set 2 | kutum
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | ecoporanga
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | richards bay
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | baturaja
# Processing Record 43 of Set 2 | lata
# Processing Record 44 of Set 2 | sawtell
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | puerto baquerizo moreno
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | fairbanks
# Processing Record 49 of Set 2 | sola
# Processing Record 0 of Set 3 | barauna
# Processing Record 1 of Set 3 | mangochi
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | formello
# Processing Record 4 of Set 3 | pietarsaari
# Processing Record 5 of Set 3 | dzaoudzi
# Processing Record 6 of Set 3 | grand-lahou
# Processing Record 7 of Set 3 | virginia beach
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | oussouye
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | amapa
# Processing Record 12 of Set 3 | ternate
# Processing Record 13 of Set 3 | olds
# Processing Record 14 of Set 3 | benguela
# Processing Record 15 of Set 3 | zhangye
# Processing Record 16 of Set 3 | menongue
# Processing Record 17 of Set 3 | saint anthony
# Processing Record 18 of Set 3 | baherden
# Processing Record 19 of Set 3 | yuci
# Processing Record 20 of Set 3 | canon city
# Processing Record 21 of Set 3 | roebourne
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | mount pleasant
# Processing Record 25 of Set 3 | yatou
# Processing Record 26 of Set 3 | sur
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | chicama
# Processing Record 29 of Set 3 | antalaha
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | cap-aux-meules
# Processing Record 32 of Set 3 | jamestown
# Processing Record 33 of Set 3 | san cristobal
# Processing Record 34 of Set 3 | busselton
# Processing Record 35 of Set 3 | omboue
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | ust-kan
# Processing Record 41 of Set 3 | bathsheba
# Processing Record 42 of Set 3 | suntar
# Processing Record 43 of Set 3 | babadag
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | olinda
# Processing Record 47 of Set 3 | amethi
# Processing Record 48 of Set 3 | vigrestad
# Processing Record 49 of Set 3 | georgetown
# Processing Record 0 of Set 4 | provideniya
# Processing Record 1 of Set 4 | byron bay
# Processing Record 2 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 4 | minsk
# Processing Record 5 of Set 4 | kambove
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | katherine
# Processing Record 8 of Set 4 | coahuayana
# Processing Record 9 of Set 4 | zig
# Processing Record 10 of Set 4 | pascagoula
# Processing Record 11 of Set 4 | lamar
# Processing Record 12 of Set 4 | macklin
# Processing Record 13 of Set 4 | seymchan
# Processing Record 14 of Set 4 | sioux lookout
# Processing Record 15 of Set 4 | tuktoyaktuk
# Processing Record 16 of Set 4 | jiexiu
# Processing Record 17 of Set 4 | lima
# Processing Record 18 of Set 4 | andenes
# Processing Record 19 of Set 4 | opuwo
# Processing Record 20 of Set 4 | lat yao
# Processing Record 21 of Set 4 | sao jose da coroa grande
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | labod
# Processing Record 24 of Set 4 | ahipara
# Processing Record 25 of Set 4 | a
# City not found. Skipping...
# Processing Record 26 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 4 | hofn
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | kamaishi
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 33 of Set 4 | pundaguitan
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | tarko-sale
# Processing Record 36 of Set 4 | saint-leu
# Processing Record 37 of Set 4 | phangnga
# Processing Record 38 of Set 4 | matagami
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | berea
# Processing Record 42 of Set 4 | yellowknife
# Processing Record 43 of Set 4 | tazovskiy
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | sarab
# Processing Record 46 of Set 4 | coos bay
# Processing Record 47 of Set 4 | yongzhou
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | paris
# Processing Record 0 of Set 5 | san luis
# Processing Record 1 of Set 5 | saiha
# Processing Record 2 of Set 5 | yerbogachen
# Processing Record 3 of Set 5 | havre-saint-pierre
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | banepa
# Processing Record 7 of Set 5 | walvis bay
# Processing Record 8 of Set 5 | riachao das neves
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | taksimo
# Processing Record 12 of Set 5 | sokolo
# Processing Record 13 of Set 5 | la rinconada
# Processing Record 14 of Set 5 | poum
# Processing Record 15 of Set 5 | agadir
# Processing Record 16 of Set 5 | guadalupe
# Processing Record 17 of Set 5 | huilong
# Processing Record 18 of Set 5 | san felipe
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | penticton
# Processing Record 22 of Set 5 | chuy
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | maragogi
# Processing Record 25 of Set 5 | biggar
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | san bartolome de tirajana
# Processing Record 28 of Set 5 | varna
# Processing Record 29 of Set 5 | kawalu
# Processing Record 30 of Set 5 | roald
# Processing Record 31 of Set 5 | wilmington
# Processing Record 32 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 5 | la palma
# Processing Record 34 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 5 | premia de mar
# Processing Record 36 of Set 5 | plettenberg bay
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | yarmouth
# Processing Record 41 of Set 5 | vanimo
# Processing Record 42 of Set 5 | amboise
# Processing Record 43 of Set 5 | tautira
# Processing Record 44 of Set 5 | dom pedrito
# Processing Record 45 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | gumushane
# City not found. Skipping...
# Processing Record 48 of Set 5 | freeport
# Processing Record 49 of Set 5 | ye
# City not found. Skipping...
# Processing Record 0 of Set 6 | mao
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | san quintin
# Processing Record 3 of Set 6 | pimentel
# Processing Record 4 of Set 6 | presidente medici
# Processing Record 5 of Set 6 | torbay
# Processing Record 6 of Set 6 | gizo
# Processing Record 7 of Set 6 | benin
# Processing Record 8 of Set 6 | dicabisagan
# Processing Record 9 of Set 6 | iskateley
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | puerto del rosario
# Processing Record 13 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 6 | tabou
# Processing Record 15 of Set 6 | mariestad
# Processing Record 16 of Set 6 | flinders
# Processing Record 17 of Set 6 | rybnaya sloboda
# Processing Record 18 of Set 6 | katangli
# Processing Record 19 of Set 6 | isangel
# Processing Record 20 of Set 6 | yeppoon
# Processing Record 21 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 6 | burica
# City not found. Skipping...
# Processing Record 23 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 6 | nioro
# Processing Record 25 of Set 6 | mahebourg
# Processing Record 26 of Set 6 | ukiah
# Processing Record 27 of Set 6 | lavrentiya
# Processing Record 28 of Set 6 | chapleau
# Processing Record 29 of Set 6 | kloulklubed
# Processing Record 30 of Set 6 | dengfeng
# Processing Record 31 of Set 6 | bonavista

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          598
# Lat           598
# Lng           598
# Max Temp      598
# Humidity      598
# Cloudiness    598
# Wind Speed    598
# Country       598
# Date          598
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   hobart -42.8794  147.3294      9.47        89         100        0.51
# 1   bentiu   9.2333   29.8333     29.24        53         100        3.00
# 2  huarmey -10.0681  -78.1522     26.92        71          99        4.49
# 3  rikitea -23.1203 -134.9692     26.30        82         100        6.48
# 4   ruston  32.5232  -92.6379     26.44        23           0        0.00
#
#   Country        Date
# 0      AU  1681759218
# 1      SS  1681759232
# 2      PE  1681759233
# 3      PF  1681759233
# 4      US  1681758639

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         hobart -42.8794  147.3294      9.47        89         100
# 1         bentiu   9.2333   29.8333     29.24        53         100
# 2        huarmey -10.0681  -78.1522     26.92        71          99
# 3        rikitea -23.1203 -134.9692     26.30        82         100
# 4         ruston  32.5232  -92.6379     26.44        23           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.51      AU  1681759218
# 1              3.00      SS  1681759232
# 2              4.49      PE  1681759233
# 3              6.48      PF  1681759233
# 4              0.00      US  1681758639

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o",edgecolors= 'black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o",edgecolors= 'black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o",edgecolors= 'black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o",edgecolors= 'black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.ylabel("Wind Speed(m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg(x_values,y_values,x_label,y_label,location):
    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot scatter plot
    plt.scatter(x_values,y_values)

    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,location,fontsize=15,color="red")

    # Label plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Print r square value
    print(f"The r-value is: {rvalue**2}")

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            bentiu   9.2333   29.8333     29.24        53         100
# 4            ruston  32.5232  -92.6379     26.44        23           0
# 5        kermanshah  34.3142   47.0650     14.50        44          20
# 6             arlit  18.7369    7.3853     32.40         8           0
# 9             tabuk  17.4189  121.4443     23.26        93          38
#
#          Wind Speed Country        Date
# City_ID
# 1              3.00      SS  1681759232
# 4              0.00      US  1681758639
# 5              2.06      IR  1681759233
# 6              4.22      NE  1681759234
# 9              1.71      PH  1681759234

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] <0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              hobart -42.8794  147.3294      9.47        89         100
# 2             huarmey -10.0681  -78.1522     26.92        71          99
# 3             rikitea -23.1203 -134.9692     26.30        82         100
# 7        constitucion -35.3333  -72.4167     15.62        51           5
# 8            hermanus -34.4187   19.2345     15.85        84           1
#
#          Wind Speed Country        Date
# City_ID
# 0              0.51      AU  1681759218
# 2              4.49      PE  1681759233
# 3              6.48      PF  1681759233
# 7              7.58      CL  1681759234
# 8              0.58      ZA  1681759234

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
x_label = 'Latitude'
y_label = 'Max Temp'
location = (6,-10)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.7600135150140623

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = 'Latitude'
y_label = 'Max Temp'
location = (-55,30)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.5604349273008364

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong linear relationship between latitude and max temperature in both the northern and southern hemisphere. In the northern hemisphere, as the latitude increases, the temperature drops. it is the vice versa in southern hemisphere. Northern hemisphere has stronger coorelation than southern.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
x_label = 'Latitude'
y_label = 'Humidity'
location = (40,10)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.1036972877923439

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
x_label = 'Latitude'
y_label = 'Humidity'
location = (-50,20)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.0724678246844836

# %% [markdown]
# **Discussion about the linear relationship:** Low r score point to very low correlation between latitude and humidity. Northern hemisphere has slightly stronger coorelation than southern.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# store x and y values
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
x_label = 'Latitude'
y_label = 'Cloudiness'
location = (6,10)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.04960738125390117

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
x_label = 'Latitude'
y_label = 'Cloudiness'
location = (-30,30)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.014217878456352456

# %% [markdown]
# **Discussion about the linear relationship:** Northern hemisphere has decent coorelation between latitude and cloudiness. As the latitude increases, the cloudiness does too. Southern hemisphere on the other hand does not show such correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
x_label = 'Latitude'
y_label = 'Wind Speed'
location = (6,10)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.009397734312217342

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
x_label = 'Latitude'
y_label = 'Wind Speed'
location = (-55,10)
lin_reg(x_values,y_values,x_label,y_label,location)
# Out:
# The r-value is: 0.03868070330618527

# %% [markdown]
# **Discussion about the linear relationship:** Northern hemisphere does not show any coorelation between latitude and wind speed. Southern hemisphere has higher correlation where windspeed decreases with latitude gain.
